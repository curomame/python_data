# %%
import pandas as pd

# %%
df2 = pd.read_csv('df2.csv')

# %%
df2.plot.line()

# %%
df2['c'].plot.line()

# %%
df2['c'].plot.line(figsize=(20,3),ls='--',c='#357421')

# %%
title = "MY PLOT TITLE"
xlabel = 'My X Data'
ylabel = 'My Y Data'

# %%
ax = df2['c'].plot.line(figsize=(10,3),ls=':',c='red',lw=5)

# %%
title='Custom Pandas Plot'
ylabel='Y-axis data'
xlabel='X-axis data'

ax = df2.plot(figsize=(8,3),title=title)
ax.set(xlabel=xlabel, ylabel=ylabel)



ax.autoscale(axis='x',tight=True)

# %%
ax = df2.plot() 
ax.legend(loc=1,bbox_to_anchor=(2.0,1.0))
